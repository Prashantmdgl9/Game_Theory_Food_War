# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sy
from matplotlib import patches
# %matplotlib inline

# %% [markdown]
# ## Where to eat?
# ## Pay off Matrix for various cuisines

# %% [markdown]
# ### Pay off Matrix for various cuisines
#
# |      | Mexican| South Indian| Italian| Chinese|Japanese
# | :----- | :-----: | :-----:|:-----: | :-----: |:-----: |
# | Varun  | 3| 1 |3 | 1 | 1 |
# | Kirti  | 1| 2 |2 | 4 | 1 |

# %%
Varun = [3, 1, 1, 3, 1]
Kirti = [1, 2, 4, 2, 1]

# %%
plt.style.use('fivethirtyeight')
fig1 = plt.figure( figsize = (8, 5))
plt.plot(Varun, Kirti)
plt.xlabel('Varun', size = 18); plt.ylabel('Kirti', size = 18); 
plt.title('Payoff Polygon', size = 20)
# Out:
# Text(0.5, 1.0, 'Payoff Polygon')

# %% [markdown]
# ## Slope of the line that is at the top and passes through (3, 2) and (1, 4)

# %%
Slope = ( 4 - 2 )/ ( 1 - 3 )

# %%
Slope
# Out:
# -1.0

# %% [markdown]
# # Equation of Line y = mx + c
# y - 2 = slope(x - 3)

# %% [markdown]
# y = - x + 5

# %% [markdown]
# xy = x (-x + 5) = - x^2 + 5x

# %%
def n(x):
    return -x**2 +5*x

# %%
x = sy.Symbol('x')

# %%
dn = sy.diff(n(x), x)

# %%
dn
# Out:
# 5 - 2*x

# %%
x = 2

# %%
sn = sy.solve(dn)

# %%
sn
# Out:
# [5/2]

# %%
sn[0]
# Out:
# 5/2

# %%
y = -sn[0] + 5
y
# Out:
# 5/2

# %%
fig1 = plt.figure( figsize = (8, 5))
plt.plot(Varun, Kirti)
plt.plot(2.5, 2.5, 'o', markersize=20, color='green')
plt.xlabel('Varun', size = 18); plt.ylabel('Kirti', size = 18); 
plt.title('Payoff Polygon', size = 20)
# Out:
# Text(0.5, 1.0, 'Payoff Polygon')

# %% [markdown]
# ### For Kirti
# 5/2 = 2p + (1-p)4
# 2p +4 -4p = 2.5  ;  -2p = -1.5; p = 3/4
#
# ### For Varun
# 5/2 = 3p + (1-p)1
# 2p + 1 = 2.5 ; 2p = 1.5 ; p = 3/4
